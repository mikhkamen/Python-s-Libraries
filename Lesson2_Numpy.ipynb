# %%
import numpy as np

# %% [markdown]
# ### Задание 1

# %%
A = np.array([[1, 6],
              [2, 8],
              [2, 11],
              [2, 10],
              [1, 7]])

# %%
mean_a  = np.mean(A, axis=0)
mean_a
# Out:
# array([1.6, 8.4])

# %% [markdown]
# ### Задание 2

# %%
a_centered = A - mean_a
a_centered
# Out:
# array([[-0.6, -2.4],
#        [ 0.4, -0.4],
#        [ 0.4,  2.6],
#        [ 0.4,  1.6],
#        [-0.6, -1.4]])

# %% [markdown]
# ### Задание 3

# %%
a_centered_sp = np.dot(a_centered[:, 0], a_centered[:, 1])
a_centered_sp
# Out:
# 3.8

# %% [markdown]
# ### Задание 4

# %%
N = A.shape[0]
A_cov = a_centered_sp / (N - 1)
A_cov
# Out:
# 0.95
